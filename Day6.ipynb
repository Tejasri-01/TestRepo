# %%
class employee:
    
    def __init__(self,name=input('Name please: '),age=int(input("Age of your's: "))):
        self.name=name
        self.age=age
        
    def payroll(self):
        self.basic=int(input('say your basic pay: '))
        self.hra=int(input('HRA : '))
        self.allowance=int(input('Allowances : '))
        self.gross=self.basic+self.hra+self.allowance
        print('The Gross Pay: ',self.gross)
        print()
        print('Employee Name: ',self.name)
        print()
        print('Employee Age: ',self.age)
        
    def display(self):
        print('The {}  and his payroll pay is {}'.format(self.name,self.gross))
obj=employee()

# %%
class person:
    def __init__(hello,name=input('enter the name'),age=int(input("enter the age"))):
        hello.name=name
        hello.age=age
    def display(hello):
        print("th{} and hisagei s{}".format(hello.name,hello.age))
per=person('john')

# %%
class Student:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
        self.id=datetime.datetime.now()
    def display(self):
        print('{} and his id {}'.format(self.firstname,self.lastname))
stu=student()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       6     def display(self):
#       7         print('{} and his id {}'.format(self.firstname,self.lastname))
# ----> 8 stu=student()
#
# NameError: name 'student' is not defined

# %%
class Learn:
    """ Learn class"""
    def __init__(self,learning_hours):
        self.__learning_hours=learning_hours
        
    def get_learning_hours(self):
        return self.__learning_hours
    
    def print_learn_status(self):
        print('Learning is in progress..')
        
    def print_status(self):
        print('Hello from learn..')
class Work:
    """
    Work class
    """
    def __init__(self,working_hours):
        self.__working_hours=working_hours
        
    def get_working_hours(self):
        return self.__working_hours
    
    def print_work_status(self):
        print('Work in Progress...')
        
    def print_status(self):
        print('Hello from Work...')
        
class Employee(Learn,Work):
    
    """
    Employee class
    """
    def __init__(self,emp_id,w_hours,l_hours):
        self.__emp_id=emp_id
        Learn.__init__(self,l_hours)
        Work.__init__(self,w_hours)
        
    def get_employee_id(self):
        return self.__emp_id
    
    
    def print_employee_id(self):
        print('121212')
        
    def print_status(self):
        print('Hello from Employee class')
    
E=Employee(1234,4,6)

# %%
e.emp_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 e.emp_id
#
# NameError: name 'e' is not defined

# %% [markdown]
# # 1.Write a python program to create a base class "Shape" with methods to calculate area and perimeter. Then, create derived classes "Circle" and "Rectangle" that inherit from the base class and calculate their respective areas and perimeters. Demonstrate their usage in a program.
#
# You are developing an online quiz application where users can take quizzes on
#
# various topics and receive scores.
#
# 1. Create a class for quizzes and questions.
#
# 2. Implement a scoring system that calculates the user's score on a quiz. 3. How would you store and retrieve user progress, including quiz history and
#
# scores?

# %%
   import math

class Shape:
    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius ** 2

    def calculate_perimeter(self):
        return 2 * math.pi * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

# Demonstrate the usage of the classes
circle = Circle(5)
print("Circle - Area:", circle.calculate_area())
print("Circle - Perimeter:", circle.calculate_perimeter())

rectangle = Rectangle(4, 6)
print("Rectangle - Area:", rectangle.calculate_area())
print("Rectangle - Perimeter:", rectangle.calculate_perimeter())
# Out:
# Circle - Area: 78.53981633974483
# Circle - Perimeter: 31.41592653589793
# Rectangle - Area: 24
# Rectangle - Perimeter: 20

# %%
class Question:
    def __init__(self, text, correct_answer):
        self.text = text
        self.correct_answer = correct_answer

class Quiz:
    def __init__(self, name):
        self.name = name
        self.questions = []

    def add_question(self, question_text, correct_answer):
        question = Question(question_text, correct_answer)
        self.questions.append(question)

    def take_quiz(self):
        score = 0
        for question in self.questions:
            print(question.text)
            answer = input("Your answer: ")
            if answer.lower() == question.correct_answer.lower():
                score += 1
        return score

# %%
class QuizApp:
    def __init__(self):
        self.users = {}  # Dictionary to store user progress

    def register_user(self, username):
        if username not in self.users:
            self.users[username] = {}

    def take_quiz(self, username, quiz):
        if username in self.users:
            user_progress = self.users[username]
            if quiz.name not in user_progress:
                user_progress[quiz.name] = quiz.take_quiz()
            else:
                print("You've already completed this quiz.")
        else:
            print("User not registered. Please register first.")

    def get_user_progress(self, username):
        if username in self.users:
            return self.users[username]
        else:
            print("User not found.")

# %%
# Create quizzes
math_quiz = Quiz("Math Quiz")
math_quiz.add_question("What is 2 + 2?", "4")
math_quiz.add_question("What is 3 x 5?", "15")

science_quiz = Quiz("Science Quiz")
science_quiz.add_question("What is the chemical symbol for water?", "H2O")
science_quiz.add_question("What is the Earth's largest continent?", "Asia")

# Create a quiz app
quiz_app = QuizApp()

# Register users
quiz_app.register_user("Alice")
quiz_app.register_user("Bob")

# Users take quizzes
quiz_app.take_quiz("Alice", math_quiz)
quiz_app.take_quiz("Bob", science_quiz)

# Get user progress
alice_progress = quiz_app.get_user_progress("Alice")
bob_progress = quiz_app.get_user_progress("Bob")

print("Alice's Progress:", alice_progress)
print("Bob's Progress:", bob_progress)
# Out:
# What is 2 + 2?
# Your answer: 4
# What is 3 x 5?
# Your answer: 15
# What is the chemical symbol for water?
# Your answer: h20
# What is the Earth's largest continent?
# Your answer: asia
# Alice's Progress: {'Math Quiz': 2}
# Bob's Progress: {'Science Quiz': 1}

# %% [markdown]
# # 2.Write a python script to create a class "Person" with private aftributes for age and name. Implement a method to calculate a person's eligibility for voting based on their age. Ensure that age cannot be accessed directly but only through a getter method.

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name  # Private attribute for name
        self.__age = age    # Private attribute for age

    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    def is_eligible_to_vote(self):
        if self.__age >= 18:
            return True
        else:
            return False

# Example usage:
if __name__ == "__main__":
    name = input("Enter person's name: ")
    age = int(input("Enter person's age: "))

    person = Person(name, age)

    print(f"{person.get_name()} is {person.get_age()} years old.")

    if person.is_eligible_to_vote():
        print(f"{person.get_name()} is eligible to vote.")
    else:
        print(f"{person.get_name()} is not eligible to vote.")
# Out:
# Enter person's name: john
# Enter person's age: 56
# john is 56 years old.
# john is eligible to vote.

# %% [markdown]
# # 3.You are tasked with designing a Python class hierarchy for a simple banking system. The system should be able to handle different types of accounts, such as Savings Accounts and Checking Accounts. Both account types should have common attributes like an account number, account holder's name, and balance. However, Savings Accounts should have an additional attribute for interest rate, while Checking Accounts should have an attribute for overdraft limit.
#
# 1. Create a Python class called BankAccount with the following attributes and methods:
#
# a. Attributes: account number, account holder_name, balance b. Methods: init__() (constructor), deposit(), and withdraw()
#
# 2. Create two subclasses. Savings Account and Checking Account, that inherit from the BankAccount class.
#
# 3. Add the following attributes and methods to each subclass:
#
# a. Savings Account:
#
# Additional attribute: interest rate
#
# ii. Method: calculate_interest(), which calculates and adds interest
#
# to the account based on the interest rate.
#
# b. Checking Account:
#
# 1. Additional attribute: overdraft limit
#
# 11. Method: withdraw(), which allows withdrawing money up to
#
# the overdraft limit (if available) without additional fees.
#
# 4. Write a program that creates instances of both Savings Account and Checking Account and demonstrates the use of their methods.
# Implement proper encapsulation by making the attributes private where necessary and providing getter and setter methods as needed.
#
# 6. Handle any potential errors or exceptions that may occur during operations like withdrawals, deposits, or interest calculations. 7. Provide comments in your code to explain the purpose of each class, attribute,
#
# and method. Note: Your code should create instances of the classes, simulate transactions, and
#
# showcase the differences between Savings Accounts and Checking Accounts.

# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance):
        self.__account_number = account_number  # Private attribute
        self.__account_holder_name = account_holder_name  # Private attribute
        self.__balance = balance  # Private attribute

    # Getter methods for private attributes
    def get_account_number(self):
        return self.__account_number

    def get_account_holder_name(self):
        return self.__account_holder_name

    def get_balance(self):
        return self.__balance

    # Setter method for balance (with validation)
    def set_balance(self, balance):
        if balance >= 0:
            self.__balance = balance
        else:
            print("Invalid balance value")

    def deposit(self, amount):
        try:
            amount = float(amount)  # Ensure amount is a valid number
            if amount > 0:
                self.__balance += amount
                return f"Deposited ${amount}. New balance: ${self.__balance}"
            else:
                return "Invalid deposit amount."
        except ValueError:
            return "Invalid input. Please provide a valid amount."

    def withdraw(self, amount):
        try:
            amount = float(amount)  # Ensure amount is a valid number
            if amount > 0 and amount <= self.__balance:
                self.__balance -= amount
                return f"Withdrew ${amount}. New balance: ${self.__balance}"
            else:
                return "Invalid withdrawal amount or insufficient balance."
        except ValueError:
            return "Invalid input. Please provide a valid amount."


class SavingsAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, interest_rate):
        super().__init__(account_number, account_holder_name, balance)
        self.__interest_rate = interest_rate  # Private attribute

    # Getter method for interest rate
    def get_interest_rate(self):
        return self.__interest_rate

    def calculate_interest(self):
        interest = (self.__interest_rate / 100) * self.get_balance()
        self.set_balance(self.get_balance() + interest)
        return f"Added interest of ${interest}. New balance: ${self.get_balance()}"


class CheckingAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, overdraft_limit):
        super().__init__(account_number, account_holder_name, balance)
        self.__overdraft_limit = overdraft_limit  # Private attribute

    # Getter method for overdraft limit
    def get_overdraft_limit(self):
        return self.__overdraft_limit

    def withdraw(self, amount):
        try:
            amount = float(amount)  # Ensure amount is a valid number
            if amount <= self.get_balance() + self.__overdraft_limit:
                self.set_balance(self.get_balance() - amount)
                return f"Withdrew ${amount}. New balance: ${self.get_balance()}"
            else:
                return "Withdrawal exceeds overdraft limit or insufficient balance."
        except ValueError:
            return "Invalid input. Please provide a valid amount."


# Create instances of SavingsAccount and CheckingAccount
savings_account = SavingsAccount("SA123456", "Alice", 1000, 3.5)  # Account with 3.5% interest rate
checking_account = CheckingAccount("CA987654", "Bob", 500, 200)    # Account with $200 overdraft limit

# Deposit money into the accounts
print(savings_account.deposit(500))  # Deposit $500 into the savings account
print(checking_account.deposit(300))  # Deposit $300 into the checking account

# Withdraw money from the accounts
print(savings_account.withdraw(200))  # Withdraw $200 from the savings account
print(checking_account.withdraw(700))  # Withdraw $700 from the checking account

# Calculate interest for the Savings Account
print(savings_account.calculate_interest())  # Calculate and add interest for the savings account

# Attempt to withdraw beyond overdraft limit for Checking Account
print(checking_account.withdraw(400))  # Attempt to withdraw $400 (exceeding overdraft limit)

# Check the final balances and account information using getter methods
print(f"Savings Account Balance: ${savings_account.get_balance()}")
print(f"Checking Account Balance: ${checking_account.get_balance()}")
print(f"Savings Account Interest Rate: {savings_account.get_interest_rate()}%")
print(f"Checking Account Overdraft Limit: ${checking_account.get_overdraft_limit()}")
# Out:
# Deposited $500.0. New balance: $1500.0
# Deposited $300.0. New balance: $800.0
# Withdrew $200.0. New balance: $1300.0
# Withdrew $700.0. New balance: $100.0
# Added interest of $45.50000000000001. New balance: $1345.5
# Withdrawal exceeds overdraft limit or insufficient balance.
# Savings Account Balance: $1345.5
# Checking Account Balance: $100.0
# Savings Account Interest Rate: 3.5%
# Checking Account Overdraft Limit: $200

# %% [markdown]
# # 4.You are developing an employee management system for a company. Ensure that the system utilizes encapsulation and polymorphism to handle different types of employees,
#
# such as full-time and part-time employees.
#
# 1. Create a base class called "Employee" with private attributes for name, employee
#
# ID, and salary. Implement getter and setter methods for these attributes. 2. Design two subclasses, "FullTimeEmployee" and "PartTimeEmployee," that inherit from "Employee." These subclasses should encapsulate specific properties like hours worked (for part-time employees) and annual salary (for full-time employees).
#
# 3. Override the salary calculation method in both subclasses to account for different payment structures. 4. Write a program that demonstrates polymorphism by creating instances of both
#
# "Full TimeEmployee" and "PartTimeEmployee." Calculate their salaries and
#
# display employee information

# %%
class Employee:
    def __init__(self, name, employee_id, salary):
        self.__name = name
        self.__employee_id = employee_id
        self.__salary = salary

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_employee_id(self):
        return self.__employee_id

    def set_employee_id(self, employee_id):
        self.__employee_id = employee_id

    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        self.__salary = salary
class FullTimeEmployee(Employee):
    def __init__(self, name, employee_id, annual_salary):
        super().__init__(name, employee_id, annual_salary)
        self.__annual_salary = annual_salary

    def get_annual_salary(self):
        return self.__annual_salary

    def set_annual_salary(self, annual_salary):
        self.__annual_salary = annual_salary

    def calculate_salary(self):
        return self.__annual_salary


class PartTimeEmployee(Employee):
    def __init__(self, name, employee_id, hours_worked, hourly_rate):
        super().__init__(name, employee_id, hours_worked * hourly_rate)
        self.__hours_worked = hours_worked
        self.__hourly_rate = hourly_rate

    def get_hours_worked(self):
        return self.__hours_worked

    def set_hours_worked(self, hours_worked):
        self.__hours_worked = hours_worked

    def get_hourly_rate(self):
        return self.__hourly_rate

    def set_hourly_rate(self, hourly_rate):
        self.__hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.__hours_worked * self.__hourly_rate
# Create instances of FullTimeEmployee and PartTimeEmployee
full_time_employee = FullTimeEmployee("John Doe", "FT123", 60000)
part_time_employee = PartTimeEmployee("Jane Smith", "PT456", 20, 15)

# Calculate salaries and display employee information
print(f"Full-Time Employee Information:")
print(f"Name: {full_time_employee.get_name()}")
print(f"Employee ID: {full_time_employee.get_employee_id()}")
print(f"Annual Salary: ${full_time_employee.calculate_salary()}\n")

print(f"Part-Time Employee Information:")
print(f"Name: {part_time_employee.get_name()}")
print(f"Employee ID: {part_time_employee.get_employee_id()}")
print(f"Hours Worked: {part_time_employee.get_hours_worked()}")
print(f"Hourly Rate: ${part_time_employee.get_hourly_rate()}")
print(f"Total Salary: ${part_time_employee.calculate_salary()}\n")
# Out:
# Full-Time Employee Information:
# Name: John Doe
# Employee ID: FT123
# Annual Salary: $60000
#
# Part-Time Employee Information:
# Name: Jane Smith
# Employee ID: PT456
# Hours Worked: 20
# Hourly Rate: $15
# Total Salary: $300

# %% [markdown]
# # 5.Library Management System-Scenario: You are developing a library management system
#
# where you need to handle books, patrons, and library transactions. 1. Create a class hierarchy that includes classes for books (e.g., Book), patrons (e.g.,
#
# Patron), and transactions (e.g., Transaction). Define attributes and methods for each class.
#
# 2. Implement encapsulation by making relevant attributes private and providing getter
#
# and setter methods where necessary. 3. Use inheritance to represent different types of books (e.g., fiction, non-fiction) as subclasses of the Book class. Ensure that each book type can have specific attributes and methods.
#
# 4. Demonstrate polymorphism by allowing patrons to check out and return books, regardless of the book type.
#
# 5. Implement a method for tracking overdue books and notifying patrons. 6. Consider scenarios like book reservations, late fees, and library staff interactions in your design.

# %%
import datetime

class Book:
    def __init__(self, title, author, ISBN, copies_available):
        self.title = title
        self.author = author
        self.ISBN = ISBN
        self.copies_available = copies_available

    def get_title(self):
        return self.title

    def get_author(self):
        return self.author

    def get_ISBN(self):
        return self.ISBN

    def get_copies_available(self):
        return self.copies_available

    def set_copies_available(self, copies):
        self.copies_available = copies

class FictionBook(Book):
    def __init__(self, title, author, ISBN, copies_available, genre):
        super().__init__(title, author, ISBN, copies_available)
        self.genre = genre

    def get_genre(self):
        return self.genre

class NonFictionBook(Book):
    def __init__(self, title, author, ISBN, copies_available, subject):
        super().__init__(title, author, ISBN, copies_available)
        self.subject = subject

    def get_subject(self):
        return self.subject

class Patron:
    def __init__(self, name, patron_id):
        self.name = name
        self.patron_id = patron_id
        self.checked_out_books = []

    def get_name(self):
        return self.name

    def get_patron_id(self):
        return self.patron_id

    def checkout_book(self, book):
        if book.get_copies_available() > 0:
            book.set_copies_available(book.get_copies_available() - 1)
            self.checked_out_books.append(book)
            return True
        else:
            return False

    def return_book(self, book):
        if book in self.checked_out_books:
            book.set_copies_available(book.get_copies_available() + 1)
            self.checked_out_books.remove(book)
            return True
        else:
            return False

class Transaction:
    def __init__(self, book, patron):
        self.book = book
        self.patron = patron
        self.checkout_date = datetime.date.today()
        self.due_date = self.checkout_date + datetime.timedelta(days=14)

    def get_checkout_date(self):
        return self.checkout_date

    def get_due_date(self):
        return self.due_date

    def is_overdue(self):
        return datetime.date.today() > self.due_date

    def calculate_late_fee(self):
        if self.is_overdue():
            days_overdue = (datetime.date.today() - self.due_date).days
            return days_overdue * 0.50  # Example late fee rate ($0.50 per day)
        else:
            return 0

# Example usage:

# Create books
fiction_book = FictionBook("The Hobbit", "J.R.R. Tolkien", "978-0547928227", 5, "Fantasy")
non_fiction_book = NonFictionBook("Sapiens", "Yuval Noah Harari", "978-0062316097", 3, "History")

# Create a patron
patron = Patron("John Smith", "P12345")

# Checkout books
patron.checkout_book(fiction_book)
patron.checkout_book(non_fiction_book)

# Create transactions for the checked-out books
transaction1 = Transaction(fiction_book, patron)
transaction2 = Transaction(non_fiction_book, patron)

# Check if a transaction is overdue and calculate late fee
print("Is Transaction 1 overdue?", transaction1.is_overdue())
print("Late Fee for Transaction 1:", transaction1.calculate_late_fee())

# Return a book
patron.return_book(fiction_book)

# Check the availability of a book
print(fiction_book.get_title(), "copies available:", fiction_book.get_copies_available())
# Out:
# Is Transaction 1 overdue? False
# Late Fee for Transaction 1: 0
# The Hobbit copies available: 5

# %% [markdown]
# # 6.Shopping Cart Scenario: You are tasked with designing a class hierarchy for an online shopping cart system. The system should handle products, shopping carts, and orders, Consider various DOP principles while designing this system.
#
# 1. Create a class hierarchy that includes classes for products (eg Product), shopping carts
#
# (eg ShoppingCart), and orders teg Order Define attributes and methods for each
#
# class
#
# 2. Implement encapsulation by making relevant attributes private and providing getter and
#
# setter methods where necessary
#
# 3. Use inheritance to represent different types of products (eg, electronics, clothing) as
#
# subclasses of the Product class Ensure that each product type can have specific attributes
#
# and methods
#
# 4 Demonstrate polymorphism by allowing various product types to be added to a shopping
#
# cart and calculate the total cost of its as the art
#
# 5. Implement a method for placing an order, which refer items from the shopping cart to
#
# an order.
#
# Consaler sommation like out of stock products, deserunts, and shipping costs in your design

# %%
class Product:
    def __init__(self, product_id, name, price, quantity_available):
        self.__product_id = product_id
        self.__name = name
        self.__price = price
        self.__quantity_available = quantity_available

    def get_product_id(self):
        return self.__product_id

    def get_name(self):
        return self.__name

    def get_price(self):
        return self.__price

    def get_quantity_available(self):
        return self.__quantity_available

    def decrease_stock(self, quantity):
        if quantity <= self.__quantity_available:
            self.__quantity_available -= quantity
        else:
            print("Error: Insufficient stock.")

class ElectronicProduct(Product):
    def __init__(self, product_id, name, price, quantity_available, warranty_period):
        super().__init__(product_id, name, price, quantity_available)
        self.__warranty_period = warranty_period

    def get_warranty_period(self):
        return self.__warranty_period

class ClothingProduct(Product):
    def __init__(self, product_id, name, price, quantity_available, size, color):
        super().__init__(product_id, name, price, quantity_available)
        self.__size = size
        self.__color = color

    def get_size(self):
        return self.__size

    def get_color(self):
        return self.__color

class ShoppingCart:
    def __init__(self):
        self.__cart_items = []

    def add_to_cart(self, product, quantity):
        self.__cart_items.append({"product": product, "quantity": quantity})

    def remove_from_cart(self, product, quantity):
        for item in self.__cart_items:
            if item["product"] == product:
                if item["quantity"] >= quantity:
                    item["quantity"] -= quantity
                else:
                    print("Error: Quantity to remove exceeds what's in the cart.")
                if item["quantity"] == 0:
                    self.__cart_items.remove(item)
                break

    def calculate_total_cost(self, discount_manager):
        total_cost = 0
        for item in self.__cart_items:
            product = item["product"]
            quantity = item["quantity"]
            total_cost += (product.get_price() * quantity)
            discount_manager.apply_discount(product, quantity)
        return total_cost

    def checkout(self, order):
        for item in self.__cart_items:
            product = item["product"]
            quantity = item["quantity"]
            product.decrease_stock(quantity)
        order.order_items = self.__cart_items
        self.__cart_items = []

class Order:
    def __init__(self, order_id):
        self.__order_id = order_id
        self.__order_items = []
        self.__total_cost = 0

    def get_order_id(self):
        return self.__order_id

    def get_order_items(self):
        return self.__order_items

    def get_total_cost(self):
        return self.__total_cost

    @property
    def order_items(self):
        return self.__order_items

    @order_items.setter
    def order_items(self, items):
        self.__order_items = items
        self.__total_cost = sum([item["product"].get_price() * item["quantity"] for item in items])

class DiscountManager:
    def __init__(self):
        self.__discounts = {}  # You can populate this with discount rules

    def apply_discount(self, product, quantity):
        # Implement discount logic based on product type and quantity
        pass

class ShippingCostCalculator:
    def __init__(self):
        self.__shipping_rates = {}  # You can populate this with shipping rates for different destinations

    def calculate_shipping_cost(self, destination):
        # Implement shipping cost calculation logic
        pass
    # Create some sample products
iphone = ElectronicProduct(1, "iPhone 13", 999.99, 10, "1 year")
shirt = ClothingProduct(2, "T-Shirt", 19.99, 50, "M", "Blue")

# Create a shopping cart
cart = ShoppingCart()

# Add products to the cart
cart.add_to_cart(iphone, 2)
cart.add_to_cart(shirt, 3)

# Create a discount manager (you can implement this with actual rules)
discount_manager = DiscountManager()

# Calculate the total cost
total_cost = cart.calculate_total_cost(discount_manager)

# Create an order
order = Order(1)
cart.checkout(order)

# Print order details
print(f"Order ID: {order.get_order_id()}")
print("Order Items:")
for item in order.get_order_items():
    product = item["product"]
    quantity = item["quantity"]
    print(f"Product: {product.get_name()}, Quantity: {quantity}, Price: ${product.get_price() * quantity}")

print(f"Total Cost: ${order.get_total_cost()}")
# Out:
# Order ID: 1
# Order Items:
# Product: iPhone 13, Quantity: 2, Price: $1999.98
# Product: T-Shirt, Quantity: 3, Price: $59.97
# Total Cost: $2059.95
